# %% [markdown]
# <html lang="en">
# <body></body>
# </html>

# %% [markdown]
# <html lang="en">
# <body>
# <h3>Predict the percentage of an student based on the no. of study hours.</h3>
# </body>
# </html>

# %%
# Import required libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#Import the data
url= "http://bit.ly/w-data"
df=pd.read_csv(url)
print("The data is imported successfully")
# Out:
# The data is imported successfully

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>DATA VISUALIZATION</h1>
#
# </body>
# </html>

# %% [markdown]
# <html lang="en">
# <body>
#
# <p>Now let's plot a graph of our data !</p>
#
# </body>
# </html>

# %%
#Plotting the distribution of scores
df.plot(x='Hours', y='Scores', style='ok')  
plt.title('Hours vs Scores')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Scored')  
plt.show()

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>Linear Regression</h1>
#
# </body>
# </html>

# %% [markdown]
# <html lang="en">
# <body>
# <p> It's time to generate training and testing data from our data ! </p>
# </body>
# </html>

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values

# We are using 80% data for training.
train = df[:(int((len(df)*0.8)))]
test = df[(int((len(df)*0.8))):]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(np.array(x), np.array(y), random_state=0)

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>Training the Model</h1>
#
# </body>
# </html>

# %%
from sklearn.linear_model import LinearRegression
linearRegressor= LinearRegression()
linearRegressor.fit(x_train, y_train)

y_predict= linearRegressor.predict(x_train)

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>Training the Algorithm</h1>
#
# </body>
# </html>

# %%
regressor = LinearRegression()  
regressor.fit(x_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line
line = regressor.coef_*x+regressor.intercept_
# Plotting for the test data
plt.scatter(x, y)
plt.plot(x, line, color='m');
plt.title('Hours vs Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Scored')
plt.show()

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>Checking the accuracy scores</h1>
#
# </body>
# </html>

# %%
print('Test Score')
print(regressor.score(x_test, y_test))
print('Training Score')
print(regressor.score(x_train, y_train))
# Out:
# Test Score
# 0.9367661043365055
# Training Score
# 0.9484509249326872

# %% [markdown]
# <html lang="en">
# <body>
#
# <h1>Making the prediction.</h1>
#
# </body>
# </html>

# %%
print(x_test)
y_predict= linearRegressor.predict(x_test)
print(y_predict)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]]
# [16.84472176 33.74557494 75.50062397 26.7864001  60.58810646 39.71058194
#  20.8213931 ]

# %% [markdown]
# <html>
# <body>
# <h3>What will be predicted score if a student studies for 9.25 hrs/ day? </h3>
# </body>
# </html>

# %%
#Let's predict the score for 9.25 hours
score = regressor.predict([[9.25]])
print('Score of student who studied for 9.25 hours a day = ', score)
# Out:
# Score of student who studied for 9.25 hours a day =  [93.89272889]
